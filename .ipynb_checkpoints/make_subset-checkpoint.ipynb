# %%
import csv
import time
import winsound
import pathlib
import pandas as pd

def get_header_and_lookup_values(file: str):
    t = pd.read_csv(file, dtype=str)
    filter_column=t.columns[0]
    wanted_values = t[filter_column].to_list()
    return filter_column, wanted_values

def filter_source_file(source_file: str, filter_column: str, wanted_values: list, chunksize=10**5):
    print('Looking for mathces in column {} inside file:{}'.format(filter_column, source_file))
    filtered_data = pd.DataFrame(index=None)
    with pd.read_csv(source_file, chunksize=chunksize, dtype=str) as reader:
        for chunk in reader:
            to_be_added = chunk.loc[chunk[filter_column].isin(wanted_values)]
            filtered_data = pd.concat([filtered_data, to_be_added])
            print('Rows in filtered data: {}'.format(filtered_data.shape[0]))
    print('done reading {}'.format(source_file))
    return filtered_data

# main
startTime = time.time()
wanted_values_file= 'wanted_values.csv'
# wanted_values_file='Oilseeds_NFMC_doc_ids.csv'
# file_full_path = pathlib.Path("data/2022-08-17_YTMC_oilseed_SUBSET.csv")
file_full_path = pathlib.Path("C:/Users/amnon/Desktop/ACCOUNTS/BASF/WS3_migration/Crop_zip_files/oil_seeds_170822/2022-08-17_YTMC_oilseed.csv")

file_name = file_full_path.stem
# iv_file_full_path = pathlib.Path('data/2022-08-17_INVB_oilseed_SUBSET.csv')
iv_file_full_path = pathlib.Path("C:/Users/amnon/Desktop/ACCOUNTS/BASF/WS3_migration/Crop_zip_files/oil_seeds_170822/2022-08-17_INVB_oilseed.csv")

iv_file_name = iv_file_full_path.stem

# create subset from YTMC
    # Get header for filtering and values
filter_column, wanted_values = get_header_and_lookup_values(wanted_values_file)
    # read source and get df of the subset
df = filter_source_file(file_full_path, filter_column, wanted_values)
    # write subset to csv
subset_file_name = file_name + '_subset'
subset_full_path = "output/"+subset_file_name+'.csv'
print('writing to new file in: '+ subset_full_path + '..', end=' ')
df.to_csv(subset_full_path, index=False)
print('done')
    # Get header for filtering and values (from result)
new_filter_column = 'C_IV_BAYER_UID'
new_wanted_values = df[iv_BAYER_UID_column].unique().tolist()
# Create subset from another file (INVB)
    # Read source (INVB) and get df of the subset
new_df = filter_source_file(iv_file_full_path, new_filter_column, new_wanted_values)
    # write subset to CSV
subset_file_name = iv_file_name + '_subset'
subset_full_path = "output/"+subset_file_name+'.csv'
print('writing to new file in: '+ subset_full_path + '..', end=' ')
new_df.to_csv(subset_full_path, index=False)
print('done')

winsound.Beep(440, 1000)
executionTime = (time.time() - startTime)
print('Execution time in seconds: ' + str(executionTime))

# %%
# combining INVB outputs - after renaming:
# csv_files = ['output/2022-08-17_INVB_oilseed_subset_NFMC.csv', 'output/2022-08-17_INVB_oilseed_subset_YTMC.csv']
# df_concat = pd.concat([pd.read_csv(f, dtype=str) for f in csv_files ], ignore_index=True)   
# df_concat.to_csv('output/2022-08-17_INVB_oilseed_subset.csv', index=False)
